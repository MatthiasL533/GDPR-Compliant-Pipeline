# %%
import pandas as pd

# Read the CSV file into a DataFrame
import pandas as pd


df = pd.read_csv('k221.csv')
df1 = pd.read_csv('k300.csv')
df2 = pd.read_csv('k500.csv')
df3 = pd.read_csv('k800.csv')
df4 = pd.read_csv('k1000.csv')

# %% [markdown]
# ## Check for Diveristy Issue
# ## Identify sensitive_attributes

# %%
#this function check the minimun number of unique values of certain features and their minimun normalised entrophy among all of the equivalent classes
#provide warming if one attributes in one equivalant class is below the entrophy threhold 

import pandas as pd
import numpy as np

def check_entropy_l_diversity(df, quasi_identifiers, sensitive_attributes, entropy_threshold):
    """
    Check and generate warnings for attributes below entropy threshold within each equivalence class,
    and provide a summary of minimum normalized entropy and unique values.
    
    Args:
        df (pd.DataFrame): The DataFrame to analyze.
        quasi_identifiers (list): Columns defining equivalence classes.
        sensitive_attributes (list): Sensitive attributes to assess.
        entropy_threshold (float): Threshold for acceptable normalized entropy.
    
    Returns:
        pd.DataFrame: Warnings for each equivalence class where entropy is below the threshold.
        pd.DataFrame: Summary data showing minimum l-values and normalized entropy.
    """
    grouped = df.groupby(quasi_identifiers)
    warnings_data = []
    min_l_values = {attr: float('inf') for attr in sensitive_attributes}
    min_entropy_values = {attr: float('inf') for attr in sensitive_attributes}
    distinct_values_count = {attr: 0 for attr in sensitive_attributes}

    # Helper function to calculate normalized entropy
    def calculate_normalized_entropy(series):
        probabilities = series.value_counts(normalize=True)
        entropy = -np.sum(probabilities * np.log2(probabilities))
        max_entropy = np.log2(len(probabilities)) if len(probabilities) > 0 else 1
        return entropy / max_entropy if max_entropy else 0

    for group_key, group_df in grouped:
        for attribute in sensitive_attributes:
            unique_count = group_df[attribute].nunique()
            normalized_entropy = calculate_normalized_entropy(group_df[attribute])
            distinct_values_count[attribute] = df[attribute].nunique()
            if unique_count < min_l_values[attribute]:
                min_l_values[attribute] = unique_count
            if normalized_entropy < min_entropy_values[attribute]:
                min_entropy_values[attribute] = normalized_entropy
            
            # Generate warning if the normalized entropy is below threshold
            if normalized_entropy < entropy_threshold:
                warnings_data.append({
                    'Equivalence Class': ', '.join(map(str, group_key)),
                    'Attribute': attribute,
                    'Normalized Entropy': normalized_entropy,
                    'Warning': f"Entropy below threshold: {normalized_entropy:.3f} (threshold: {entropy_threshold})"
                })

    warnings_df = pd.DataFrame(warnings_data)
    if warnings_df.empty:
        warnings_df = pd.DataFrame(columns=['Equivalence Class', 'Attribute', 'Normalized Entropy', 'Warning'])
        warnings_df.loc[0] = ["No classes", "N/A", "N/A", "All attributes meet entropy thresholds."]

    # Create DataFrame for summary data
    summary_data = {
        'Attribute': [],
        'Min Unique Values': [],
        'Min Normalized Entropy': [],
        'Distinct Values': []
    }
    for attribute, min_val in min_l_values.items():
        summary_data['Attribute'].append(attribute)
        summary_data['Min Unique Values'].append(min_val)
        summary_data['Min Normalized Entropy'].append(min_entropy_values[attribute])
        summary_data['Distinct Values'].append(distinct_values_count[attribute])

    summary_df = pd.DataFrame(summary_data)

    return warnings_df, summary_df

# Example usage
quasi_identifiers = ['race', 'gender', 'age']
sensitive_attributes = ['diag_1', 'diag_2', 'diag_3', 'max_glu_serum', 'A1Cresult', 'readmitted']
entropy_threshold = 0.25

# Assuming 'df' is your DataFrame containing the data
warnings_report, summary_report = check_entropy_l_diversity(df, quasi_identifiers, sensitive_attributes, entropy_threshold)

# Displaying the reports
print("\nSummary of Minimum l Values and Entropy:")
print(summary_report)

print("\nEntropy Warnings Report:")
warnings_report
# Out:
# Summary of Minimum l Values and Entropy:
#        Attribute  Min Unique Values  Min Normalized Entropy  Distinct Values
# 0         diag_1                  8                0.606566               10
# 1         diag_2                  8                0.562586               10
# 2         diag_3                  8                0.674722               10
# 3  max_glu_serum                  3                0.067771                4
# 4      A1Cresult                  4                0.361971                4
# 5     readmitted                  2                0.285435                2
#
# Entropy Warnings Report:
#                     Equivalence Class      Attribute  Normalized Entropy  \
# 0     AfricanAmerican, Female, [0-40)  max_glu_serum            0.067771
# 1    AfricanAmerican, Female, [40-50)  max_glu_serum            0.115360
# 2    AfricanAmerican, Female, [50-60)  max_glu_serum            0.073586
# 3    AfricanAmerican, Female, [60-70)  max_glu_serum            0.085473
# 4    AfricanAmerican, Female, [70-80)  max_glu_serum            0.103420
# 5   AfricanAmerican, Female, [80-100)  max_glu_serum            0.104294
# 6       AfricanAmerican, Male, [0-40)  max_glu_serum            0.110076
# 7      AfricanAmerican, Male, [40-50)  max_glu_serum            0.153275
# 8      AfricanAmerican, Male, [50-60)  max_glu_serum            0.091531
# 9      AfricanAmerican, Male, [60-70)  max_glu_serum            0.117123
# 10     AfricanAmerican, Male, [70-80)  max_glu_serum            0.088836
# 11    AfricanAmerican, Male, [80-100)  max_glu_serum            0.095530
# 12          Caucasian, Female, [0-40)  max_glu_serum            0.172727
# 13         Caucasian, Female, [40-50)  max_glu_serum            0.204081
# 14         Caucasian, Female, [50-60)  max_glu_serum            0.176039
# 15         Caucasian, Female, [60-70)  max_glu_serum            0.182745
# 16         Caucasian, Female, [70-80)  max_glu_serum            0.227337
# 17            Caucasian, Male, [0-40)  max_glu_serum            0.180812
# 18           Caucasian, Male, [40-50)  max_glu_serum            0.208313
# 19           Caucasian, Male, [50-60)  max_glu_serum            0.182666
# 20           Caucasian, Male, [60-70)  max_glu_serum            0.155710
# 21           Caucasian, Male, [70-80)  max_glu_serum            0.225394
# 22          Caucasian, Male, [80-100)  max_glu_serum            0.240505
# 23              other, Female, [0-40)  max_glu_serum            0.161880
# 24             other, Female, [40-50)  max_glu_serum            0.240580
# 25             other, Female, [50-60)  max_glu_serum            0.227552
# 26             other, Female, [60-70)  max_glu_serum            0.230750
# 27             other, Female, [70-80)  max_glu_serum            0.194755
# 28            other, Female, [80-100)  max_glu_serum            0.148791
# 29               other, Male, [40-50)  max_glu_serum            0.143721
# 30               other, Male, [50-60)  max_glu_serum            0.119880
# 31               other, Male, [60-70)  max_glu_serum            0.171154
# 32               other, Male, [70-80)  max_glu_serum            0.174714
# 33              other, Male, [80-100)  max_glu_serum            0.176890
#
#                                              Warning
# 0   Entropy below threshold: 0.068 (threshold: 0.25)
# 1   Entropy below threshold: 0.115 (threshold: 0.25)
# 2   Entropy below threshold: 0.074 (threshold: 0.25)
# 3   Entropy below threshold: 0.085 (threshold: 0.25)
# 4   Entropy below threshold: 0.103 (threshold: 0.25)
# 5   Entropy below threshold: 0.104 (threshold: 0.25)
# 6   Entropy below threshold: 0.110 (threshold: 0.25)
# 7   Entropy below threshold: 0.153 (threshold: 0.25)
# 8   Entropy below threshold: 0.092 (threshold: 0.25)
# 9   Entropy below threshold: 0.117 (threshold: 0.25)
# 10  Entropy below threshold: 0.089 (threshold: 0.25)
# 11  Entropy below threshold: 0.096 (threshold: 0.25)
# 12  Entropy below threshold: 0.173 (threshold: 0.25)
# 13  Entropy below threshold: 0.204 (threshold: 0.25)
# 14  Entropy below threshold: 0.176 (threshold: 0.25)
# 15  Entropy below threshold: 0.183 (threshold: 0.25)
# 16  Entropy below threshold: 0.227 (threshold: 0.25)
# 17  Entropy below threshold: 0.181 (threshold: 0.25)
# 18  Entropy below threshold: 0.208 (threshold: 0.25)
# 19  Entropy below threshold: 0.183 (threshold: 0.25)
# 20  Entropy below threshold: 0.156 (threshold: 0.25)
# 21  Entropy below threshold: 0.225 (threshold: 0.25)
# 22  Entropy below threshold: 0.241 (threshold: 0.25)
# 23  Entropy below threshold: 0.162 (threshold: 0.25)
# 24  Entropy below threshold: 0.241 (threshold: 0.25)
# 25  Entropy below threshold: 0.228 (threshold: 0.25)
# 26  Entropy below threshold: 0.231 (threshold: 0.25)
# 27  Entropy below threshold: 0.195 (threshold: 0.25)
# 28  Entropy below threshold: 0.149 (threshold: 0.25)
# 29  Entropy below threshold: 0.144 (threshold: 0.25)
# 30  Entropy below threshold: 0.120 (threshold: 0.25)
# 31  Entropy below threshold: 0.171 (threshold: 0.25)
# 32  Entropy below threshold: 0.175 (threshold: 0.25)
# 33  Entropy below threshold: 0.177 (threshold: 0.25)

# %% [markdown]
# ## Entropy l diveristy

# %% [markdown]
# Normalized Entropy:
#
# Normalized entropy is computed by dividing the actual entropy by the maximum possible entropy (i.e., the entropy that would occur if every category were equally likely).
# Formula:
# ![image.png](attachment:image.png)
#
# The result is a value between 0 and 1:
# 1 indicates perfect uniformity (maximum diversity, where all outcomes are equally probable).
# 0 indicates no diversity at all (a single outcome dominates completely).
# Values near 0 indicate that the data is highly skewed towards one or a few outcomes.
# Higher values closer to 1 indicate greater diversity and lesser predictability.

# %%
# More Detailed Normalized Entropy L-Diversity Report with Warnings

def entropy_l_diversity_report(df, quasi_identifiers, sensitive_attributes, entropy_threshold=0.5):
    """
    Generate a detailed report per equivalence class showing the normalized entropy l-diversity value for all selected sensitive attributes.
    Also includes warnings if any sensitive attribute has normalized entropy below the specified threshold.
    
    Args:
        df (pd.DataFrame): The input DataFrame.
        quasi_identifiers (list): The list of columns defining equivalence classes.
        sensitive_attributes (list): The list of sensitive attributes to assess entropy l-diversity.
        entropy_threshold (float): The minimum required normalized entropy value for each sensitive attribute.
    
    Returns:
        pd.DataFrame: A detailed DataFrame with normalized entropy values per equivalence class and per sensitive attribute.
    """
    # Group by quasi-identifiers to form equivalence classes
    grouped = df.groupby(quasi_identifiers)

    # List to collect entropy values per equivalence class
    report_data = []

    # Function to calculate normalized entropy given a series of values
    def calculate_normalized_entropy(series):
        probabilities = series.value_counts(normalize=True)
        entropy = -np.sum(probabilities * np.log2(probabilities))
        max_entropy = np.log2(len(probabilities)) if len(probabilities) > 0 else 1
        return entropy / max_entropy if max_entropy else 0  # Normalize the entropy

    # Iterate through each group (equivalence class)
    for group_key, group_df in grouped:
        # Initialize an empty dictionary to store details for each equivalence class
        class_info = dict(zip(quasi_identifiers, group_key))
        
        # Initialize a list to collect warnings for the current equivalence class
        warnings = []

        # Calculate the normalized entropy for each sensitive attribute in this class
        for sensitive_attribute in sensitive_attributes:
            entropy_value = calculate_normalized_entropy(group_df[sensitive_attribute])
            class_info[f'{sensitive_attribute} - Normalized Entropy'] = entropy_value

            # Find the most frequent value(s) for this attribute
            dominant_value_counts = group_df[sensitive_attribute].value_counts()
            dominant_value = dominant_value_counts.index[0]
            dominant_count = dominant_value_counts.iloc[0]
            class_info[f'{sensitive_attribute} - Dominant Value'] = dominant_value
            class_info[f'{sensitive_attribute} - Dominant Count'] = dominant_count

            # Add a warning if the normalized entropy is below the specified threshold
            if entropy_value < entropy_threshold:
                warnings.append(f"{sensitive_attribute} normalized entropy is {entropy_value:.3f}, below {entropy_threshold}. Dominant value: {dominant_value} with count {dominant_count}")

        # Add warnings to the report for this equivalence class
        class_info['Warnings'] = "; ".join(warnings) if warnings else "No diversity issues"

        # Collect all the entropy values in this class for reporting
        report_data.append(class_info)

    # Convert the collected data to a DataFrame for easier analysis
    return pd.DataFrame(report_data)

# Example usage:

# Define the quasi-identifiers and sensitive attributes
quasi_identifiers = ['race', 'gender', 'age']
sensitive_attributes = ['diag_1', 'diag_2', 'diag_3', 'max_glu_serum', 'A1Cresult', 'readmitted']

detailed_report = entropy_l_diversity_report(df, quasi_identifiers, sensitive_attributes, entropy_threshold=0.25)

# Display the detailed report
print("\nNormalized Entropy L-Diversity Report with Warnings:")
detailed_report
# Out:
# Normalized Entropy L-Diversity Report with Warnings:
#                race  gender       age  diag_1 - Normalized Entropy  \
# 0   AfricanAmerican  Female    [0-40)                     0.718071
# 1   AfricanAmerican  Female   [40-50)                     0.800054
# 2   AfricanAmerican  Female   [50-60)                     0.826443
# 3   AfricanAmerican  Female   [60-70)                     0.827115
# 4   AfricanAmerican  Female   [70-80)                     0.809295
# 5   AfricanAmerican  Female  [80-100)                     0.853621
# 6   AfricanAmerican    Male    [0-40)                     0.606566
# 7   AfricanAmerican    Male   [40-50)                     0.770948
# 8   AfricanAmerican    Male   [50-60)                     0.800384
# 9   AfricanAmerican    Male   [60-70)                     0.796608
# 10  AfricanAmerican    Male   [70-80)                     0.797046
# 11  AfricanAmerican    Male  [80-100)                     0.764917
# 12        Caucasian  Female    [0-40)                     0.702053
# 13        Caucasian  Female   [40-50)                     0.795321
# 14        Caucasian  Female   [50-60)                     0.847941
# 15        Caucasian  Female   [60-70)                     0.856815
# 16        Caucasian  Female   [70-80)                     0.839410
# 17        Caucasian  Female  [80-100)                     0.831619
# 18        Caucasian    Male    [0-40)                     0.633322
# 19        Caucasian    Male   [40-50)                     0.795926
# 20        Caucasian    Male   [50-60)                     0.802413
# 21        Caucasian    Male   [60-70)                     0.813036
# 22        Caucasian    Male   [70-80)                     0.812017
# 23        Caucasian    Male  [80-100)                     0.821002
# 24            other  Female    [0-40)                     0.705212
# 25            other  Female   [40-50)                     0.828457
# 26            other  Female   [50-60)                     0.873412
# 27            other  Female   [60-70)                     0.866435
# 28            other  Female   [70-80)                     0.844656
# 29            other  Female  [80-100)                     0.881035
# 30            other    Male    [0-40)                     0.698218
# 31            other    Male   [40-50)                     0.805437
# 32            other    Male   [50-60)                     0.807945
# 33            other    Male   [60-70)                     0.800997
# 34            other    Male   [70-80)                     0.806063
# 35            other    Male  [80-100)                     0.797387
#
#    diag_1 - Dominant Value  diag_1 - Dominant Count  \
# 0                    other                      604
# 1                    other                      543
# 2              circulatory                      689
# 3              circulatory                      793
# 4              circulatory                      887
# 5              circulatory                      508
# 6                    other                      457
# 7                    other                      469
# 8              circulatory                      575
# 9              circulatory                      654
# 10             circulatory                      480
# 11             circulatory                      204
# 12                   other                     1104
# 13                   other                     1081
# 14                   other                     1492
# 15             circulatory                     2309
# 16             circulatory                     3500
# 17             circulatory                     3216
# 18                   other                      947
# 19                   other                     1117
# 20             circulatory                     2136
# 21             circulatory                     3300
# 22             circulatory                     3735
# 23             circulatory                     2181
# 24                   other                      129
# 25                   other                      107
# 26                   other                      154
# 27             circulatory                      198
# 28             circulatory                      246
# 29             circulatory                      168
# 30                   other                      125
# 31                   other                      167
# 32             circulatory                      218
# 33             circulatory                      295
# 34             circulatory                      274
# 35             circulatory                       97
#
#     diag_2 - Normalized Entropy diag_2 - Dominant Value  \
# 0                      0.696027                   other
# 1                      0.740319                   other
# 2                      0.773739                   other
# 3                      0.760154             circulatory
# 4                      0.764972             circulatory
# 5                      0.719521             circulatory
# 6                      0.562586                   other
# 7                      0.691128                   other
# 8                      0.751289                   other
# 9                      0.764534             circulatory
# 10                     0.749459             circulatory
# 11                     0.743397             circulatory
# 12                     0.661322                   other
# 13                     0.737096                   other
# 14                     0.817931                   other
# 15                     0.818408                   other
# 16                     0.798082             circulatory
# 17                     0.764552             circulatory
# 18                     0.592095                   other
# 19                     0.748215                   other
# 20                     0.782446                   other
# 21                     0.785060             circulatory
# 22                     0.776750             circulatory
# 23                     0.762106             circulatory
# 24                     0.725302                   other
# 25                     0.779222                   other
# 26                     0.812618                   other
# 27                     0.842100                   other
# 28                     0.820127             circulatory
# 29                     0.807400             circulatory
# 30                     0.682223                   other
# 31                     0.774406                   other
# 32                     0.799713                   other
# 33                     0.828705             circulatory
# 34                     0.794131             circulatory
# 35                     0.772153             circulatory
#
#     diag_2 - Dominant Count  diag_3 - Normalized Entropy  ...  \
# 0                       655                     0.734184  ...
# 1                       651                     0.760331  ...
# 2                       840                     0.771467  ...
# 3                       898                     0.770731  ...
# 4                       878                     0.758071  ...
# 5                       586                     0.746371  ...
# 6                       474                     0.674722  ...
# 7                       565                     0.731808  ...
# 8                       646                     0.755211  ...
# 9                       687                     0.762423  ...
# 10                      515                     0.766075  ...
# 11                      203                     0.769505  ...
# 12                     1247                     0.721369  ...
# 13                     1359                     0.724187  ...
# 14                     1991                     0.783561  ...
# 15                     2393                     0.790645  ...
# 16                     3742                     0.792552  ...
# 17                     3695                     0.770041  ...
# 18                     1024                     0.682742  ...
# 19                     1446                     0.721204  ...
# 20                     2106                     0.751609  ...
# 21                     3111                     0.776072  ...
# 22                     3858                     0.778680  ...
# 23                     2472                     0.769863  ...
# 24                      141                     0.694872  ...
# 25                      141                     0.749479  ...
# 26                      193                     0.790584  ...
# 27                      217                     0.782170  ...
# 28                      248                     0.787671  ...
# 29                      170                     0.766117  ...
# 30                      129                     0.764469  ...
# 31                      184                     0.740587  ...
# 32                      231                     0.787058  ...
# 33                      273                     0.811902  ...
# 34                      268                     0.790769  ...
# 35                      118                     0.797744  ...
#
#    max_glu_serum - Normalized Entropy  max_glu_serum - Dominant Value  \
# 0                            0.067771                               0
# 1                            0.115360                               0
# 2                            0.073586                               0
# 3                            0.085473                               0
# 4                            0.103420                               0
# 5                            0.104294                               0
# 6                            0.110076                               0
# 7                            0.153275                               0
# 8                            0.091531                               0
# 9                            0.117123                               0
# 10                           0.088836                               0
# 11                           0.095530                               0
# 12                           0.172727                               0
# 13                           0.204081                               0
# 14                           0.176039                               0
# 15                           0.182745                               0
# 16                           0.227337                               0
# 17                           0.250285                               0
# 18                           0.180812                               0
# 19                           0.208313                               0
# 20                           0.182666                               0
# 21                           0.155710                               0
# 22                           0.225394                               0
# 23                           0.240505                               0
# 24                           0.161880                               0
# 25                           0.240580                               0
# 26                           0.227552                               0
# 27                           0.230750                               0
# 28                           0.194755                               0
# 29                           0.148791                               0
# 30                           0.297921                               0
# 31                           0.143721                               0
# 32                           0.119880                               0
# 33                           0.171154                               0
# 34                           0.174714                               0
# 35                           0.176890                               0
#
#     max_glu_serum - Dominant Count  A1Cresult - Normalized Entropy  \
# 0                             1245                        0.595818
# 1                             1503                        0.474670
# 2                             2416                        0.486961
# 3                             2381                        0.397894
# 4                             2388                        0.414324
# 5                             1541                        0.361971
# 6                              704                        0.644674
# 7                             1190                        0.583389
# 8                             1728                        0.517040
# 9                             1749                        0.428711
# 10                            1337                        0.420189
# 11                             570                        0.371823
# 12                            2071                        0.524328
# 13                            2755                        0.518094
# 14                            5293                        0.477180
# 15                            7493                        0.425932
# 16                           10032                        0.384651
# 17                            9592                        0.373632
# 18                            1498                        0.612457
# 19                            3014                        0.563098
# 20                            5960                        0.505326
# 21                            8433                        0.438838
# 22                            9340                        0.382054
# 23                            6068                        0.372900
# 24                             309                        0.583126
# 25                             313                        0.544302
# 26                             519                        0.549109
# 27                             688                        0.497082
# 28                             737                        0.475184
# 29                             533                        0.464265
# 30                             199                        0.597870
# 31                             414                        0.582869
# 32                             621                        0.537133
# 33                             780                        0.509572
# 34                             674                        0.476709
# 35                             329                        0.476318
#
#     A1Cresult - Dominant Value  A1Cresult - Dominant Count  \
# 0                            0                         899
# 1                            0                        1257
# 2                            0                        1982
# 3                            0                        2088
# 4                            0                        2092
# 5                            0                        1389
# 6                            0                         488
# 7                            0                         918
# 8                            0                        1397
# 9                            0                        1522
# 10                           0                        1160
# 11                           0                         508
# 12                           0                        1650
# 13                           0                        2322
# 14                           0                        4540
# 15                           0                        6684
# 16                           0                        9340
# 17                           0                        9067
# 18                           0                        1081
# 19                           0                        2416
# 20                           0                        5026
# 21                           0                        7394
# 22                           0                        8704
# 23                           0                        5720
# 24                           0                         233
# 25                           0                         258
# 26                           0                         431
# 27                           0                         597
# 28                           0                         642
# 29                           0                         460
# 30                           0                         148
# 31                           0                         318
# 32                           0                         495
# 33                           0                         653
# 34                           0                         582
# 35                           0                         284
#
#     readmitted - Normalized Entropy  readmitted - Dominant Value  \
# 0                          0.492619                            0
# 1                          0.524436                            0
# 2                          0.448406                            0
# 3                          0.499680                            0
# 4                          0.537518                            0
# 5                          0.517018                            0
# 6                          0.529837                            0
# 7                          0.532136                            0
# 8                          0.480014                            0
# 9                          0.531970                            0
# 10                         0.505937                            0
# 11                         0.500383                            0
# 12                         0.562938                            0
# 13                         0.482177                            0
# 14                         0.485373                            0
# 15                         0.497914                            0
# 16                         0.519802                            0
# 17                         0.534643                            0
# 18                         0.475391                            0
# 19                         0.463630                            0
# 20                         0.448147                            0
# 21                         0.511461                            0
# 22                         0.529120                            0
# 23                         0.521225                            0
# 24                         0.347041                            0
# 25                         0.359356                            0
# 26                         0.346012                            0
# 27                         0.477939                            0
# 28                         0.472638                            0
# 29                         0.477505                            0
# 30                         0.285435                            0
# 31                         0.525337                            0
# 32                         0.378623                            0
# 33                         0.446108                            0
# 34                         0.513067                            0
# 35                         0.610563                            0
#
#     readmitted - Dominant Count  \
# 0                          1128
# 1                          1364
# 2                          2227
# 3                          2162
# 4                          2149
# 5                          1398
# 6                           637
# 7                          1090
# 8                          1585
# 9                          1585
# 10                         1213
# 11                          517
# 12                         1887
# 13                         2622
# 14                         4974
# 15                         7030
# 16                         9499
# 17                         9117
# 18                         1417
# 19                         2889
# 20                         5689
# 21                         7798
# 22                         8807
# 23                         5778
# 24                          302
# 25                          314
# 26                          520
# 27                          663
# 28                          702
# 29                          498
# 30                          210
# 31                          379
# 32                          593
# 33                          742
# 34                          627
# 35                          294
#
#                                              Warnings
# 0   max_glu_serum normalized entropy is 0.068, bel...
# 1   max_glu_serum normalized entropy is 0.115, bel...
# 2   max_glu_serum normalized entropy is 0.074, bel...
# 3   max_glu_serum normalized entropy is 0.085, bel...
# 4   max_glu_serum normalized entropy is 0.103, bel...
# 5   max_glu_serum normalized entropy is 0.104, bel...
# 6   max_glu_serum normalized entropy is 0.110, bel...
# 7   max_glu_serum normalized entropy is 0.153, bel...
# 8   max_glu_serum normalized entropy is 0.092, bel...
# 9   max_glu_serum normalized entropy is 0.117, bel...
# 10  max_glu_serum normalized entropy is 0.089, bel...
# 11  max_glu_serum normalized entropy is 0.096, bel...
# 12  max_glu_serum normalized entropy is 0.173, bel...
# 13  max_glu_serum normalized entropy is 0.204, bel...
# 14  max_glu_serum normalized entropy is 0.176, bel...
# 15  max_glu_serum normalized entropy is 0.183, bel...
# 16  max_glu_serum normalized entropy is 0.227, bel...
# 17                                No diversity issues
# 18  max_glu_serum normalized entropy is 0.181, bel...
# 19  max_glu_serum normalized entropy is 0.208, bel...
# 20  max_glu_serum normalized entropy is 0.183, bel...
# 21  max_glu_serum normalized entropy is 0.156, bel...
# 22  max_glu_serum normalized entropy is 0.225, bel...
# 23  max_glu_serum normalized entropy is 0.241, bel...
# 24  max_glu_serum normalized entropy is 0.162, bel...
# 25  max_glu_serum normalized entropy is 0.241, bel...
# 26  max_glu_serum normalized entropy is 0.228, bel...
# 27  max_glu_serum normalized entropy is 0.231, bel...
# 28  max_glu_serum normalized entropy is 0.195, bel...
# 29  max_glu_serum normalized entropy is 0.149, bel...
# 30                                No diversity issues
# 31  max_glu_serum normalized entropy is 0.144, bel...
# 32  max_glu_serum normalized entropy is 0.120, bel...
# 33  max_glu_serum normalized entropy is 0.171, bel...
# 34  max_glu_serum normalized entropy is 0.175, bel...
# 35  max_glu_serum normalized entropy is 0.177, bel...
#
# [36 rows x 22 columns]

# %% [markdown]
# # Achiveing L-diveristy through suppression /deleting data /adding sythetic data

# %% [markdown]
# # Deleting Data for l-diveristy

# %% [raw]
# import pandas as pd
# import numpy as np
#
# def achieve_entropy_l_diversity_by_suppression(df, quasi_identifiers, sensitive_attributes, entropy_threshold):
#     """
#     Modify the DataFrame to ensure each equivalence class satisfies normalized entropy l-diversity
#     by suppressing values that do not meet the threshold and provide information about data suppression
#     and minimum normalized entropy l-values.
#
#     Args:
#         df (pd.DataFrame): The DataFrame to modify.
#         quasi_identifiers (list): Columns defining equivalence classes.
#         sensitive_attributes (list): Sensitive attributes to anonymize.
#         entropy_threshold (float): Threshold for acceptable normalized entropy.
#
#     Returns:
#         pd.DataFrame: Modified DataFrame satisfying entropy l-diversity.
#         dict: Information about the data suppression and minimum normalized entropy l-values.
#     """
#     def calculate_normalized_entropy(series):
#         probabilities = series.value_counts(normalize=True)
#         entropy = -np.sum(probabilities * np.log2(probabilities))
#         max_entropy = np.log2(len(probabilities)) if len(probabilities) > 0 else 1
#         return entropy / max_entropy if max_entropy else 0
#
#     # Create a copy of the dataframe to avoid modifying the original one
#     modified_df = df.copy()
#     grouped = modified_df.groupby(quasi_identifiers, group_keys=False)
#
#     min_normalized_entropies = {attribute: float('inf') for attribute in sensitive_attributes}
#     suppression_info = {attribute: 0 for attribute in sensitive_attributes}
#
#     for group_key, group_df in grouped:
#         for attribute in sensitive_attributes:
#             normalized_entropy = calculate_normalized_entropy(group_df[attribute])
#
#             while normalized_entropy < entropy_threshold and not group_df.empty:
#                 # Find the value counts once and suppress the most common value
#                 value_counts = group_df[attribute].value_counts()
#                 most_common_value = value_counts.idxmax()
#                 most_common_value_indices = group_df[group_df[attribute] == most_common_value].index
#
#                 # Suppress all occurrences of the most common value at once
#                 modified_df.loc[most_common_value_indices, attribute] = '<SUPPRESSED>'
#                 suppression_info[attribute] += len(most_common_value_indices)
#
#                 # Update the group_df for recalculating entropy
#                 group_df.loc[most_common_value_indices, attribute] = '<SUPPRESSED>'
#
#                 # Recalculate entropy after suppression
#                 normalized_entropy = calculate_normalized_entropy(group_df[attribute])
#
#             # Update the minimum normalized entropy for this attribute
#             if normalized_entropy < min_normalized_entropies[attribute]:
#                 min_normalized_entropies[attribute] = normalized_entropy
#
#     # Calculate data suppression information
#     total_suppressed = sum(suppression_info.values())
#     original_row_count = len(df)
#     suppression_percentage = (total_suppressed / (original_row_count * len(sensitive_attributes))) * 100
#
#     suppression_info.update({
#         'Original Row Count': original_row_count,
#         'Total Suppressed': total_suppressed,
#         'Suppression Percentage': suppression_percentage,
#         'Min Normalized Entropies': min_normalized_entropies
#     })
#
#     return modified_df, suppression_info
#
# # Example usage
# quasi_identifiers = ['race', 'gender', 'age']
# sensitive_attributes = ['diag_1', 'diag_2', 'diag_3', 'max_glu_serum', 'A1Cresult', 'readmitted']
# entropy_threshold = 0.25
#
# # Assuming 'df' is your DataFrame containing the data
# modified_df, suppression_info = achieve_entropy_l_diversity_by_suppression(df, quasi_identifiers, sensitive_attributes, entropy_threshold)
#
# # Displaying the modified DataFrame and suppression information
# print("Modified DataFrame:")
# print(modified_df)
#
# print("\nSuppression Information:")
# print(suppression_info)

# %%
# Experiment under the different value for l=0.25,0.3,0.35


def achieve_entropy_l_diversity_by_deletion(df, quasi_identifiers, sensitive_attributes, entropy_threshold):
    """
    Modify the DataFrame to ensure each equivalence class satisfies normalized entropy l-diversity
    by deleting rows that do not meet the threshold and provide information about data loss and 
    minimum normalized entropy l-values.
    
    Args:
        df (pd.DataFrame): The DataFrame to modify.
        quasi_identifiers (list): Columns defining equivalence classes.
        sensitive_attributes (list): Sensitive attributes to anonymize.
        entropy_threshold (float): Threshold for acceptable normalized entropy.
    
    Returns:
        pd.DataFrame: Modified DataFrame satisfying entropy l-diversity.
        dict: Information about the data loss and minimum normalized entropy l-values.
    """
    def calculate_normalized_entropy(series):
        probabilities = series.value_counts(normalize=True)
        entropy = -np.sum(probabilities * np.log2(probabilities))
        max_entropy = np.log2(len(probabilities)) if len(probabilities) > 0 else 1
        return entropy / max_entropy if max_entropy else 0

    # Create a copy of the dataframe to avoid modifying the original one
    modified_df = df.copy()
    grouped = modified_df.groupby(quasi_identifiers)
    
    rows_to_delete = []
    min_normalized_entropies = {attribute: float('inf') for attribute in sensitive_attributes}

    for group_key, group_df in grouped:
        for attribute in sensitive_attributes:
            normalized_entropy = calculate_normalized_entropy(group_df[attribute])
            
            while normalized_entropy < entropy_threshold and not group_df.empty:
                # Find the row with the highest frequency for this attribute and mark it for deletion
                most_common_value = group_df[attribute].value_counts().idxmax()
                row_to_delete = group_df[group_df[attribute] == most_common_value].index[0]
                rows_to_delete.append(row_to_delete)
                group_df = group_df.drop(row_to_delete)
                
                # Recalculate entropy after deletion
                normalized_entropy = calculate_normalized_entropy(group_df[attribute])
            
            # Update the minimum normalized entropy for this attribute
            if normalized_entropy < min_normalized_entropies[attribute]:
                min_normalized_entropies[attribute] = normalized_entropy
    
    # Drop the marked rows from the dataframe
    modified_df = modified_df.drop(rows_to_delete)
    
    # Calculate data loss information
    original_row_count = len(df)
    modified_row_count = len(modified_df)
    rows_deleted = original_row_count - modified_row_count
    data_loss_percentage = (rows_deleted / original_row_count) * 100

    data_loss_info = {
        'Original Row Count': original_row_count,
        'Modified Row Count': modified_row_count,
        'Rows Deleted': rows_deleted,
        'Data Loss Percentage': data_loss_percentage,
        'Min Normalized Entropies': min_normalized_entropies
    }
    
    return modified_df, data_loss_info

# Example usage
quasi_identifiers = ['race', 'gender', 'age']
sensitive_attributes = ['diag_1', 'diag_2', 'diag_3', 'max_glu_serum', 'A1Cresult', 'readmitted']
entropy_threshold = 0.25

# Assuming 'df' is your DataFrame containing the data
modified_df, data_loss_info = achieve_entropy_l_diversity_by_deletion(df, quasi_identifiers, sensitive_attributes, entropy_threshold)

# Displaying the modified DataFrame and data loss information
print("Modified DataFrame:")
print(modified_df)

print("\nData Loss Information:")
print(data_loss_info)
# Out:
# Modified DataFrame:
#         encounter_id  patient_nbr             race  gender       age  \
# 8              12522     48330783        Caucasian  Female  [80-100)
# 9              15738     63555939        Caucasian  Female  [80-100)
# 23            183930    107400762        Caucasian  Female  [80-100)
# 29            252822     18196434        Caucasian  Female  [80-100)
# 44            450210     80177094        Caucasian  Female  [80-100)
# ...              ...          ...              ...     ...       ...
# 101758     443847548    100162476  AfricanAmerican    Male   [70-80)
# 101759     443847782     74694222  AfricanAmerican  Female  [80-100)
# 101760     443854148     41088789        Caucasian    Male   [70-80)
# 101761     443857166     31693671        Caucasian  Female  [80-100)
# 101762     443867222    175429310        Caucasian    Male   [70-80)
#
#         admission_type_id discharge_disposition_id admission_source_id  \
# 8                       1                     Home            Transfer
# 9                       1                 Facility            Transfer
# 23                      1                     Home            Referral
# 29                      1                 Facility               Other
# 44                      1                  Expired               Other
# ...                   ...                      ...                 ...
# 101758                  1                 Facility               Other
# 101759                  1                 Facility            Transfer
# 101760                  1                     Home               Other
# 101761                  1                 Facility               Other
# 101762                  1                     Home               Other
#
#         time_in_hospital  num_lab_procedures  ...  tolazamide  insulin  \
# 8                     13                  68  ...         -20        0
# 9                     12                  33  ...         -20        0
# 23                    11                  42  ...         -20      -20
# 29                     5                  52  ...         -20      -20
# 44                     7                  72  ...         -20        0
# ...                  ...                 ...  ...         ...      ...
# 101758                 3                  51  ...         -20      -10
# 101759                 5                  33  ...         -20        0
# 101760                 1                  53  ...         -20      -10
# 101761                10                  45  ...         -20       10
# 101762                 6                  13  ...         -20      -20
#
#         glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# 8                       -20                  -20                       -20
# 9                       -20                  -20                       -20
# 23                      -20                  -20                       -20
# 29                      -20                  -20                       -20
# 44                      -20                  -20                       -20
# ...                     ...                  ...                       ...
# 101758                  -20                  -20                       -20
# 101759                  -20                  -20                       -20
# 101760                  -20                  -20                       -20
# 101761                  -20                  -20                       -20
# 101762                  -20                  -20                       -20
#
#        metformin-rosiglitazone metformin-pioglitazone change  diabetesMed  \
# 8                          -20                    -20      1            1
# 9                          -20                    -20      1            1
# 23                         -20                    -20      0            0
# 29                         -20                    -20      1            1
# 44                         -20                    -20      0            1
# ...                        ...                    ...    ...          ...
# 101758                     -20                    -20      1            1
# 101759                     -20                    -20      0            1
# 101760                     -20                    -20      1            1
# 101761                     -20                    -20      1            1
# 101762                     -20                    -20      0            0
#
#         readmitted
# 8                0
# 9                0
# 23               0
# 29               0
# 44               0
# ...            ...
# 101758           0
# 101759           0
# 101760           0
# 101761           0
# 101762           0
#
# [70357 rows x 45 columns]
#
# Data Loss Information:
# {'Original Row Count': 101763, 'Modified Row Count': 70357, 'Rows Deleted': 31406, 'Data Loss Percentage': 30.861904621522555, 'Min Normalized Entropies': {'diag_1': 0.6065663711474752, 'diag_2': 0.5625862222640018, 'diag_3': 0.6747215037152028, 'max_glu_serum': 0.2500041547846993, 'A1Cresult': 0.35061920278105224, 'readmitted': 0.28543510909778447}}

# %%
output_path = "l025.csv"


modified_df.to_csv(output_path, index=False)

# %%
quasi_identifiers = ['race', 'gender', 'age']
sensitive_attributes = ['diag_1', 'diag_2', 'diag_3', 'max_glu_serum', 'A1Cresult', 'readmitted']
entropy_threshold = 0.3

# Assuming 'df' is your DataFrame containing the data
modified_df, data_loss_info = achieve_entropy_l_diversity_by_deletion(df, quasi_identifiers, sensitive_attributes, entropy_threshold)

# Displaying the modified DataFrame and data loss information
print("Modified DataFrame:")
print(modified_df)

print("\nData Loss Information:")
print(data_loss_info)
# Out:
# Modified DataFrame:
#         encounter_id  patient_nbr             race  gender       age  \
# 133          2265486     44279478        Caucasian    Male   [70-80)
# 135          2292606     53848278  AfricanAmerican  Female   [70-80)
# 142          2309268     77475465        Caucasian  Female  [80-100)
# 144          2311404     95586993        Caucasian  Female  [80-100)
# 153          2430276     69318126        Caucasian    Male   [70-80)
# ...              ...          ...              ...     ...       ...
# 101758     443847548    100162476  AfricanAmerican    Male   [70-80)
# 101759     443847782     74694222  AfricanAmerican  Female  [80-100)
# 101760     443854148     41088789        Caucasian    Male   [70-80)
# 101761     443857166     31693671        Caucasian  Female  [80-100)
# 101762     443867222    175429310        Caucasian    Male   [70-80)
#
#         admission_type_id discharge_disposition_id admission_source_id  \
# 133                     0                     Home            Referral
# 135                     0                     Home               Other
# 142                     0                     Home               Other
# 144                     0                 Facility               Other
# 153                     0                     Home               Other
# ...                   ...                      ...                 ...
# 101758                  1                 Facility               Other
# 101759                  1                 Facility            Transfer
# 101760                  1                     Home               Other
# 101761                  1                 Facility               Other
# 101762                  1                     Home               Other
#
#         time_in_hospital  num_lab_procedures  ...  tolazamide  insulin  \
# 133                    6                  55  ...         -20      -20
# 135                   13                  75  ...         -20      -20
# 142                    9                  42  ...         -20        0
# 144                   11                  70  ...         -20      -20
# 153                    7                  82  ...         -20      -20
# ...                  ...                 ...  ...         ...      ...
# 101758                 3                  51  ...         -20      -10
# 101759                 5                  33  ...         -20        0
# 101760                 1                  53  ...         -20      -10
# 101761                10                  45  ...         -20       10
# 101762                 6                  13  ...         -20      -20
#
#         glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# 133                     -20                  -20                       -20
# 135                     -20                  -20                       -20
# 142                     -20                  -20                       -20
# 144                     -20                  -20                       -20
# 153                     -20                  -20                       -20
# ...                     ...                  ...                       ...
# 101758                  -20                  -20                       -20
# 101759                  -20                  -20                       -20
# 101760                  -20                  -20                       -20
# 101761                  -20                  -20                       -20
# 101762                  -20                  -20                       -20
#
#        metformin-rosiglitazone metformin-pioglitazone change  diabetesMed  \
# 133                        -20                    -20      1            1
# 135                        -20                    -20      0            1
# 142                        -20                    -20      0            1
# 144                        -20                    -20      0            0
# 153                        -20                    -20      0            0
# ...                        ...                    ...    ...          ...
# 101758                     -20                    -20      1            1
# 101759                     -20                    -20      0            1
# 101760                     -20                    -20      1            1
# 101761                     -20                    -20      1            1
# 101762                     -20                    -20      0            0
#
#         readmitted
# 133              0
# 135              0
# 142              0
# 144              0
# 153              0
# ...            ...
# 101758           0
# 101759           0
# 101760           0
# 101761           0
# 101762           0
#
# [55468 rows x 45 columns]
#
# Data Loss Information:
# {'Original Row Count': 101763, 'Modified Row Count': 55468, 'Rows Deleted': 46295, 'Data Loss Percentage': 45.492959130528774, 'Min Normalized Entropies': {'diag_1': 0.6065663711474752, 'diag_2': 0.5625862222640018, 'diag_3': 0.6747215037152028, 'max_glu_serum': 0.30000769104800423, 'A1Cresult': 0.3574763788081661, 'readmitted': 0.30065994958038167}}

# %%
output_path = "l03.csv"


modified_df.to_csv(output_path, index=False)

# %%
quasi_identifiers = ['race', 'gender', 'age']
sensitive_attributes = ['diag_1', 'diag_2', 'diag_3', 'max_glu_serum', 'A1Cresult', 'readmitted']
entropy_threshold = 0.35

# Assuming 'df' is your DataFrame containing the data
modified_df, data_loss_info = achieve_entropy_l_diversity_by_deletion(df, quasi_identifiers, sensitive_attributes, entropy_threshold)

# Displaying the modified DataFrame and data loss information
print("Modified DataFrame:")
print(modified_df)

print("\nData Loss Information:")
print(data_loss_info)
# Out:
# Modified DataFrame:
#         encounter_id  patient_nbr             race  gender       age  \
# 133          2265486     44279478        Caucasian    Male   [70-80)
# 135          2292606     53848278  AfricanAmerican  Female   [70-80)
# 142          2309268     77475465        Caucasian  Female  [80-100)
# 144          2311404     95586993        Caucasian  Female  [80-100)
# 153          2430276     69318126        Caucasian    Male   [70-80)
# ...              ...          ...              ...     ...       ...
# 101758     443847548    100162476  AfricanAmerican    Male   [70-80)
# 101759     443847782     74694222  AfricanAmerican  Female  [80-100)
# 101760     443854148     41088789        Caucasian    Male   [70-80)
# 101761     443857166     31693671        Caucasian  Female  [80-100)
# 101762     443867222    175429310        Caucasian    Male   [70-80)
#
#         admission_type_id discharge_disposition_id admission_source_id  \
# 133                     0                     Home            Referral
# 135                     0                     Home               Other
# 142                     0                     Home               Other
# 144                     0                 Facility               Other
# 153                     0                     Home               Other
# ...                   ...                      ...                 ...
# 101758                  1                 Facility               Other
# 101759                  1                 Facility            Transfer
# 101760                  1                     Home               Other
# 101761                  1                 Facility               Other
# 101762                  1                     Home               Other
#
#         time_in_hospital  num_lab_procedures  ...  tolazamide  insulin  \
# 133                    6                  55  ...         -20      -20
# 135                   13                  75  ...         -20      -20
# 142                    9                  42  ...         -20        0
# 144                   11                  70  ...         -20      -20
# 153                    7                  82  ...         -20      -20
# ...                  ...                 ...  ...         ...      ...
# 101758                 3                  51  ...         -20      -10
# 101759                 5                  33  ...         -20        0
# 101760                 1                  53  ...         -20      -10
# 101761                10                  45  ...         -20       10
# 101762                 6                  13  ...         -20      -20
#
#         glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# 133                     -20                  -20                       -20
# 135                     -20                  -20                       -20
# 142                     -20                  -20                       -20
# 144                     -20                  -20                       -20
# 153                     -20                  -20                       -20
# ...                     ...                  ...                       ...
# 101758                  -20                  -20                       -20
# 101759                  -20                  -20                       -20
# 101760                  -20                  -20                       -20
# 101761                  -20                  -20                       -20
# 101762                  -20                  -20                       -20
#
#        metformin-rosiglitazone metformin-pioglitazone change  diabetesMed  \
# 133                        -20                    -20      1            1
# 135                        -20                    -20      0            1
# 142                        -20                    -20      0            1
# 144                        -20                    -20      0            0
# 153                        -20                    -20      0            0
# ...                        ...                    ...    ...          ...
# 101758                     -20                    -20      1            1
# 101759                     -20                    -20      0            1
# 101760                     -20                    -20      1            1
# 101761                     -20                    -20      1            1
# 101762                     -20                    -20      0            0
#
#         readmitted
# 133              0
# 135              0
# 142              0
# 144              0
# 153              0
# ...            ...
# 101758           0
# 101759           0
# 101760           0
# 101761           0
# 101762           0
#
# [44981 rows x 45 columns]
#
# Data Loss Information:
# {'Original Row Count': 101763, 'Modified Row Count': 44981, 'Rows Deleted': 56782, 'Data Loss Percentage': 55.79827638729205, 'Min Normalized Entropies': {'diag_1': 0.6065663711474752, 'diag_2': 0.5625862222640018, 'diag_3': 0.6747215037152028, 'max_glu_serum': 0.3500000087920946, 'A1Cresult': 0.3729569256201798, 'readmitted': 0.35056382068186565}}

# %%
output_path = "l035.csv"


modified_df.to_csv(output_path, index=False)

# %% [markdown]
# # Check the data loss

# %%
df1 = pd.read_csv('l025.csv')
df2 = pd.read_csv('l03.csv')
df3 = pd.read_csv('l035.csv')

# %%
import matplotlib.pyplot as plt

# Example DataFrames for demonstration (assuming df1, df2, df3 are defined somewhere in your code)
dataframes = [df, df1, df2, df3]

# Corresponding names for the DataFrames (adjust to match the number of DataFrames)
df_names = ['Original DF','DF with Entropy 0.25', 'DF with Entropy 0.3', 'DF with Entropy 0.35']

# Calculate the size (number of rows) of each DataFrame
sizes = [len(df) for df in dataframes]

# Calculate the maximum size to determine percentages
max_size = max(sizes)
percentages = [(size / max_size) * 100 for size in sizes]

# Create a bar chart
plt.figure(figsize=(10, 6))  # Set the figure size
bars = plt.bar(df_names, sizes, color='skyblue')  # Create a bar chart

# Add number of rows and percentage labels to each bar
for bar, size, percentage in zip(bars, sizes, percentages):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, f'{size}\n({percentage:.2f}%)', ha='center', va='bottom', fontsize=8)

plt.xlabel('DataFrame (with different entropy l-diversity thresholds)')  # Label for the x-axis
plt.ylabel('Number of Rows')  # Label for the y-axis
plt.title('Comparison of DataFrame Sizes under Different Entropy l-Diversity Levels')  # Title of the plot
plt.show()

# %% [markdown]
# # Check the Data Utility

# %%
import os
import sys
import pandas as pd

# Ensure the directory path is correctly specified
directory_path = '/Users/fanfan/Desktop/Exploratory data analysis/exploratory-data-analysis-zefan'
sys.path.append(os.path.abspath(directory_path))

# Import functions from the module
import data_utils


target_column = 'readmitted'

# Encode the DataFrame
encoded_df1, encoding_info = data_utils.encode_categorical_features(df1, exclude_columns=None)
encoded_df2, encoding_info = data_utils.encode_categorical_features(df2, exclude_columns=None)
encoded_df3, encoding_info = data_utils.encode_categorical_features(df3, exclude_columns=None)

# %%
# Import machine learning functions from ml_utils
from ml_utils import run_ml_models


# Run models and get predictions
results = run_ml_models(encoded_df1, target_column)

# Displaying the results
print("Logistic Regression Results:")
print(f"Accuracy: {results['Logistic Regression']['accuracy']:.2f}")
print(f"Predictions: {results['Logistic Regression']['predictions']}")

print("\nRandom Forest Results:")
print(f"Accuracy: {results['Random Forest']['accuracy']:.2f}")
print(f"Predictions: {results['Random Forest']['predictions']}")
# Out:
# Accuracy for Logistic Regression: 0.89
# Accuracy for Random Forest: 0.89
# Logistic Regression Results:
# Accuracy: 0.89
# Predictions: [0 0 0 ... 0 0 0]
#
# Random Forest Results:
# Accuracy: 0.89
# Predictions: [0 0 0 ... 0 0 0]

# %%
# Run models and get predictions
results = run_ml_models(encoded_df2, target_column)

# Displaying the results
print("Logistic Regression Results:")
print(f"Accuracy: {results['Logistic Regression']['accuracy']:.2f}")
print(f"Predictions: {results['Logistic Regression']['predictions']}")

print("\nRandom Forest Results:")
print(f"Accuracy: {results['Random Forest']['accuracy']:.2f}")
print(f"Predictions: {results['Random Forest']['predictions']}")
# Out:
# Accuracy for Logistic Regression: 0.89
# Accuracy for Random Forest: 0.89
# Logistic Regression Results:
# Accuracy: 0.89
# Predictions: [0 0 0 ... 0 0 0]
#
# Random Forest Results:
# Accuracy: 0.89
# Predictions: [0 0 0 ... 0 0 0]

# %%
# Run models and get predictions
results = run_ml_models(encoded_df3, target_column)

# Displaying the results
print("Logistic Regression Results:")
print(f"Accuracy: {results['Logistic Regression']['accuracy']:.2f}")
print(f"Predictions: {results['Logistic Regression']['predictions']}")

print("\nRandom Forest Results:")
print(f"Accuracy: {results['Random Forest']['accuracy']:.2f}")
print(f"Predictions: {results['Random Forest']['predictions']}")
# Out:
# Accuracy for Logistic Regression: 0.89
# Accuracy for Random Forest: 0.89
# Logistic Regression Results:
# Accuracy: 0.89
# Predictions: [0 0 0 ... 0 0 0]
#
# Random Forest Results:
# Accuracy: 0.89
# Predictions: [0 0 0 ... 0 0 0]

# %%
# main_script.py

import os
import sys
import pandas as pd
import matplotlib.pyplot as plt

# Ensure the directory path is correctly specified
directory_path = '/Users/fanfan/Desktop/Exploratory data analysis/exploratory-data-analysis-zefan'
sys.path.append(os.path.abspath(directory_path))

# Import encoding function from data_utils
from data_utils import encode_categorical_features

# Import machine learning functions from ml_utils
from ml_utils import run_ml_models


target_column = 'readmitted'

# Define entropy l-diversity thresholds and their corresponding DataFrames
entropy_thresholds = ['Original', 'Entropy 0.25', 'Entropy 0.3', 'Entropy 0.35']
diverse_dfs = [df, encoded_df1, encoded_df2, encoded_df3]  # Assuming these are your DataFrames

# Store accuracies for plotting
lr_accuracies = []
rf_accuracies = []

for i, diverse_df in enumerate(diverse_dfs):
    # Encode the DataFrame
    encoded_df, _ = encode_categorical_features(diverse_df, exclude_columns=None)
    
    # Run models and get predictions
    results = run_ml_models(encoded_df, target_column)
    
    # Store accuracies
    lr_accuracies.append(results['Logistic Regression']['accuracy'])
    rf_accuracies.append(results['Random Forest']['accuracy'])

# Plot the accuracies
fig, ax = plt.subplots()
bar_width = 0.35
index = range(len(entropy_thresholds))

bar1 = plt.bar(index, lr_accuracies, bar_width, label='Logistic Regression')
bar2 = plt.bar([i + bar_width for i in index], rf_accuracies, bar_width, label='Random Forest')

plt.xlabel('Dataset')
plt.ylabel('Accuracy')
plt.title('Model Accuracy for Different Datasets with Varying l-Diversity')
plt.xticks([i + bar_width / 2 for i in index], entropy_thresholds)
plt.ylim(0, 1)  # Set y-axis limits to [0, 1]
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Accuracy for Logistic Regression: 0.89
# Accuracy for Random Forest: 0.89
# Accuracy for Logistic Regression: 0.89
# Accuracy for Random Forest: 0.89
# Accuracy for Logistic Regression: 0.89
# Accuracy for Random Forest: 0.89
# Accuracy for Logistic Regression: 0.89
# Accuracy for Random Forest: 0.89
