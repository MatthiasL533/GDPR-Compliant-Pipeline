# %%
import pandas as pd

# Read the CSV file into a DataFrame
import pandas as pd


df = pd.read_csv('k221.csv')
df1 = pd.read_csv('k300.csv')
df2 = pd.read_csv('k500.csv')
df3 = pd.read_csv('k800.csv')
df4 = pd.read_csv('k1000.csv')

# %% [markdown]
# ## Check for Distribution Issue under t-closeness

# %% [markdown]
# The parameter t in t-closeness is a threshold that determines how close the distribution of a sensitive attribute within an equivalence class should be to the distribution of the same attribute in the overall dataset.

# %% [markdown]
# Earth Mover's Distance (EMD)
# To measure the "distance" between the distributions, Earth Mover's Distance (EMD) is often used. EMD provides a way to quantify the difference between two probability distributions. The idea is to compute the minimum amount of "work" needed to transform one distribution into the other.

# %% [markdown]
# The Parameter
#
# Threshold
#
# t: This is the maximum acceptable distance (according to EMD) between the class distribution and the global distribution for the equivalence class to be considered t-close.
#
# A smaller t means the distributions need to be more similar, enforcing stricter privacy.
#
# A larger t allows more divergence between the distributions, providing more flexibility but potentially less privacy.

# %%
import pandas as pd
from scipy.stats import wasserstein_distance
import numpy as np

def calculate_distribution(series, all_categories=None):
    counts = series.value_counts(normalize=True)
    if all_categories is not None:
        counts = counts.reindex(all_categories, fill_value=0)
    return counts

def earth_mover_distance_numeric(p, q):
    return wasserstein_distance(p, q)

def earth_mover_distance_categorical(p, q):
    p, q = p.align(q, fill_value=0)
    categories = np.arange(len(p))
    return wasserstein_distance(categories, categories, p.values, q.values)

def calculate_t_closeness_emd(df, quasi_identifiers, sensitive_attribute, attribute_type='categorical'):
    global_distribution = calculate_distribution(df[sensitive_attribute])
    all_categories = global_distribution.index
    t_values = {}
    
    grouped = df.groupby(quasi_identifiers)
    for group_key, group_df in grouped:
        class_distribution = calculate_distribution(group_df[sensitive_attribute], all_categories)
        
        if attribute_type == 'numerical':
            emd = earth_mover_distance_numeric(global_distribution.values, class_distribution.values)
        else:
            emd = earth_mover_distance_categorical(global_distribution, class_distribution)
        
        t_values[group_key] = emd
    
    return t_values

def max_t_closeness_summary(df, quasi_identifiers, sensitive_attributes, attribute_types):
    max_t_values = {}
    detailed_t_values = {}
    range_t_values = {}
    
    for sensitive_attribute, attribute_type in zip(sensitive_attributes, attribute_types):
        t_values = calculate_t_closeness_emd(df, quasi_identifiers, sensitive_attribute, attribute_type)
        detailed_t_values[sensitive_attribute] = t_values
        
        if t_values:
            max_t_values[sensitive_attribute] = max(t_values.values())
            range_t_values[sensitive_attribute] = (min(t_values.values()), max(t_values.values()))
        else:
            max_t_values[sensitive_attribute] = 0.0
            range_t_values[sensitive_attribute] = (0.0, 0.0)
    
    return max_t_values, detailed_t_values, range_t_values



# Example usage
quasi_identifiers = ['race', 'gender', 'age']
sensitive_attributes = ['diag_1', 'diag_2', 'diag_3', 'max_glu_serum', 'A1Cresult', 'readmitted']
attribute_types = ['categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical']

# Calculate the maximum t-values for the sensitive attributes and the detailed t-values for each equivalence class
max_t_values, detailed_t_values, range_t_values = max_t_closeness_summary(df, quasi_identifiers, sensitive_attributes, attribute_types)

# Print the summary
print("Maximum t-values for each sensitive attribute:")
for attr, max_t in max_t_values.items():
    print(f"{attr}: {max_t:.4f}")

print("\nRange of t-values for each sensitive attribute:")
for attr, t_range in range_t_values.items():
    print(f"{attr}: Min t = {t_range[0]:.4f}, Max t = {t_range[1]:.4f}")

print("\nDetailed t-values for each equivalence class and sensitive attribute:")
for attr, class_t_values in detailed_t_values.items():
    print(f"\n{attr}:")
    for class_key, t_value in class_t_values.items():
        print(f"  Class {class_key}: {t_value:.4f}")

# Example decision process for tuning t
t_values_df = pd.DataFrame(detailed_t_values)
print("\nT-values DataFrame:\n", t_values_df)

# Plotting the distribution of t-values for each sensitive attribute
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
for attr in sensitive_attributes:
    sns.histplot(t_values_df[attr].dropna(), kde=True, label=attr)

plt.xlabel('t-value (EMD)')
plt.ylabel('Frequency')
plt.title('Distribution of t-values for Sensitive Attributes')
plt.legend()
plt.show()
# Out:
# Maximum t-values for each sensitive attribute:
# diag_1: 1.8920
# diag_2: 1.5966
# diag_3: 0.9000
# max_glu_serum: 0.1343
# A1Cresult: 0.2101
# readmitted: 0.0618
#
# Range of t-values for each sensitive attribute:
# diag_1: Min t = 0.0674, Max t = 1.8920
# diag_2: Min t = 0.0640, Max t = 1.5966
# diag_3: Min t = 0.0420, Max t = 0.9000
# max_glu_serum: Min t = 0.0034, Max t = 0.1343
# A1Cresult: Min t = 0.0135, Max t = 0.2101
# readmitted: Min t = 0.0004, Max t = 0.0618
#
# Detailed t-values for each equivalence class and sensitive attribute:
#
# diag_1:
#   Class ('AfricanAmerican', 'Female', '[0-40)'): 0.9035
#   Class ('AfricanAmerican', 'Female', '[40-50)'): 0.2039
#   Class ('AfricanAmerican', 'Female', '[50-60)'): 0.1222
#   Class ('AfricanAmerican', 'Female', '[60-70)'): 0.0674
#   Class ('AfricanAmerican', 'Female', '[70-80)'): 0.1642
#   Class ('AfricanAmerican', 'Female', '[80-100)'): 0.1245
#   Class ('AfricanAmerican', 'Male', '[0-40)'): 0.7452
#   Class ('AfricanAmerican', 'Male', '[40-50)'): 0.3705
#   Class ('AfricanAmerican', 'Male', '[50-60)'): 0.2111
#   Class ('AfricanAmerican', 'Male', '[60-70)'): 0.2142
#   Class ('AfricanAmerican', 'Male', '[70-80)'): 0.2257
#   Class ('AfricanAmerican', 'Male', '[80-100)'): 0.3842
#   Class ('Caucasian', 'Female', '[0-40)'): 0.9003
#   Class ('Caucasian', 'Female', '[40-50)'): 0.2295
#   Class ('Caucasian', 'Female', '[50-60)'): 0.1530
#   Class ('Caucasian', 'Female', '[60-70)'): 0.1999
#   Class ('Caucasian', 'Female', '[70-80)'): 0.1318
#   Class ('Caucasian', 'Female', '[80-100)'): 0.1226
#   Class ('Caucasian', 'Male', '[0-40)'): 0.6502
#   Class ('Caucasian', 'Male', '[40-50)'): 0.2498
#   Class ('Caucasian', 'Male', '[50-60)'): 0.1916
#   Class ('Caucasian', 'Male', '[60-70)'): 0.1323
#   Class ('Caucasian', 'Male', '[70-80)'): 0.1242
#   Class ('Caucasian', 'Male', '[80-100)'): 0.1102
#   Class ('other', 'Female', '[0-40)'): 1.8920
#   Class ('other', 'Female', '[40-50)'): 0.3824
#   Class ('other', 'Female', '[50-60)'): 0.1504
#   Class ('other', 'Female', '[60-70)'): 0.2354
#   Class ('other', 'Female', '[70-80)'): 0.1010
#   Class ('other', 'Female', '[80-100)'): 0.1194
#   Class ('other', 'Male', '[0-40)'): 0.5133
#   Class ('other', 'Male', '[40-50)'): 0.2816
#   Class ('other', 'Male', '[50-60)'): 0.1594
#   Class ('other', 'Male', '[60-70)'): 0.2086
#   Class ('other', 'Male', '[70-80)'): 0.1577
#   Class ('other', 'Male', '[80-100)'): 0.2345
#
# diag_2:
#   Class ('AfricanAmerican', 'Female', '[0-40)'): 0.6826
#   Class ('AfricanAmerican', 'Female', '[40-50)'): 0.1792
#   Class ('AfricanAmerican', 'Female', '[50-60)'): 0.0707
#   Class ('AfricanAmerican', 'Female', '[60-70)'): 0.1371
#   Class ('AfricanAmerican', 'Female', '[70-80)'): 0.1060
#   Class ('AfricanAmerican', 'Female', '[80-100)'): 0.2593
#   Class ('AfricanAmerican', 'Male', '[0-40)'): 0.7462
#   Class ('AfricanAmerican', 'Male', '[40-50)'): 0.3683
#   Class ('AfricanAmerican', 'Male', '[50-60)'): 0.1475
#   Class ('AfricanAmerican', 'Male', '[60-70)'): 0.1338
#   Class ('AfricanAmerican', 'Male', '[70-80)'): 0.2131
#   Class ('AfricanAmerican', 'Male', '[80-100)'): 0.2358
#   Class ('Caucasian', 'Female', '[0-40)'): 0.7882
#   Class ('Caucasian', 'Female', '[40-50)'): 0.2466
#   Class ('Caucasian', 'Female', '[50-60)'): 0.1872
#   Class ('Caucasian', 'Female', '[60-70)'): 0.1375
#   Class ('Caucasian', 'Female', '[70-80)'): 0.1049
#   Class ('Caucasian', 'Female', '[80-100)'): 0.1534
#   Class ('Caucasian', 'Male', '[0-40)'): 0.5202
#   Class ('Caucasian', 'Male', '[40-50)'): 0.2255
#   Class ('Caucasian', 'Male', '[50-60)'): 0.0640
#   Class ('Caucasian', 'Male', '[60-70)'): 0.0789
#   Class ('Caucasian', 'Male', '[70-80)'): 0.1458
#   Class ('Caucasian', 'Male', '[80-100)'): 0.2097
#   Class ('other', 'Female', '[0-40)'): 1.5966
#   Class ('other', 'Female', '[40-50)'): 0.4707
#   Class ('other', 'Female', '[50-60)'): 0.2226
#   Class ('other', 'Female', '[60-70)'): 0.2906
#   Class ('other', 'Female', '[70-80)'): 0.1826
#   Class ('other', 'Female', '[80-100)'): 0.1051
#   Class ('other', 'Male', '[0-40)'): 0.4539
#   Class ('other', 'Male', '[40-50)'): 0.2889
#   Class ('other', 'Male', '[50-60)'): 0.1544
#   Class ('other', 'Male', '[60-70)'): 0.2760
#   Class ('other', 'Male', '[70-80)'): 0.1714
#   Class ('other', 'Male', '[80-100)'): 0.1725
#
# diag_3:
#   Class ('AfricanAmerican', 'Female', '[0-40)'): 0.4785
#   Class ('AfricanAmerican', 'Female', '[40-50)'): 0.1184
#   Class ('AfricanAmerican', 'Female', '[50-60)'): 0.0492
#   Class ('AfricanAmerican', 'Female', '[60-70)'): 0.0660
#   Class ('AfricanAmerican', 'Female', '[70-80)'): 0.1196
#   Class ('AfricanAmerican', 'Female', '[80-100)'): 0.1382
#   Class ('AfricanAmerican', 'Male', '[0-40)'): 0.3868
#   Class ('AfricanAmerican', 'Male', '[40-50)'): 0.2314
#   Class ('AfricanAmerican', 'Male', '[50-60)'): 0.1044
#   Class ('AfricanAmerican', 'Male', '[60-70)'): 0.0862
#   Class ('AfricanAmerican', 'Male', '[70-80)'): 0.0748
#   Class ('AfricanAmerican', 'Male', '[80-100)'): 0.1135
#   Class ('Caucasian', 'Female', '[0-40)'): 0.6118
#   Class ('Caucasian', 'Female', '[40-50)'): 0.1725
#   Class ('Caucasian', 'Female', '[50-60)'): 0.0724
#   Class ('Caucasian', 'Female', '[60-70)'): 0.0420
#   Class ('Caucasian', 'Female', '[70-80)'): 0.0908
#   Class ('Caucasian', 'Female', '[80-100)'): 0.0891
#   Class ('Caucasian', 'Male', '[0-40)'): 0.3325
#   Class ('Caucasian', 'Male', '[40-50)'): 0.2644
#   Class ('Caucasian', 'Male', '[50-60)'): 0.1535
#   Class ('Caucasian', 'Male', '[60-70)'): 0.0649
#   Class ('Caucasian', 'Male', '[70-80)'): 0.0834
#   Class ('Caucasian', 'Male', '[80-100)'): 0.1243
#   Class ('other', 'Female', '[0-40)'): 0.9000
#   Class ('other', 'Female', '[40-50)'): 0.2587
#   Class ('other', 'Female', '[50-60)'): 0.1258
#   Class ('other', 'Female', '[60-70)'): 0.1340
#   Class ('other', 'Female', '[70-80)'): 0.0929
#   Class ('other', 'Female', '[80-100)'): 0.0920
#   Class ('other', 'Male', '[0-40)'): 0.3416
#   Class ('other', 'Male', '[40-50)'): 0.2112
#   Class ('other', 'Male', '[50-60)'): 0.1021
#   Class ('other', 'Male', '[60-70)'): 0.1911
#   Class ('other', 'Male', '[70-80)'): 0.1403
#   Class ('other', 'Male', '[80-100)'): 0.1702
#
# max_glu_serum:
#   Class ('AfricanAmerican', 'Female', '[0-40)'): 0.0627
#   Class ('AfricanAmerican', 'Female', '[40-50)'): 0.0312
#   Class ('AfricanAmerican', 'Female', '[50-60)'): 0.0627
#   Class ('AfricanAmerican', 'Female', '[60-70)'): 0.0553
#   Class ('AfricanAmerican', 'Female', '[70-80)'): 0.0495
#   Class ('AfricanAmerican', 'Female', '[80-100)'): 0.0477
#   Class ('AfricanAmerican', 'Male', '[0-40)'): 0.0367
#   Class ('AfricanAmerican', 'Male', '[40-50)'): 0.0171
#   Class ('AfricanAmerican', 'Male', '[50-60)'): 0.0597
#   Class ('AfricanAmerican', 'Male', '[60-70)'): 0.0448
#   Class ('AfricanAmerican', 'Male', '[70-80)'): 0.0568
#   Class ('AfricanAmerican', 'Male', '[80-100)'): 0.0679
#   Class ('Caucasian', 'Female', '[0-40)'): 0.0205
#   Class ('Caucasian', 'Female', '[40-50)'): 0.0150
#   Class ('Caucasian', 'Female', '[50-60)'): 0.0066
#   Class ('Caucasian', 'Female', '[60-70)'): 0.0035
#   Class ('Caucasian', 'Female', '[70-80)'): 0.0221
#   Class ('Caucasian', 'Female', '[80-100)'): 0.0363
#   Class ('Caucasian', 'Male', '[0-40)'): 0.0232
#   Class ('Caucasian', 'Male', '[40-50)'): 0.0238
#   Class ('Caucasian', 'Male', '[50-60)'): 0.0034
#   Class ('Caucasian', 'Male', '[60-70)'): 0.0202
#   Class ('Caucasian', 'Male', '[70-80)'): 0.0193
#   Class ('Caucasian', 'Male', '[80-100)'): 0.0305
#   Class ('other', 'Female', '[0-40)'): 0.0193
#   Class ('other', 'Female', '[40-50)'): 0.0445
#   Class ('other', 'Female', '[50-60)'): 0.0285
#   Class ('other', 'Female', '[60-70)'): 0.0258
#   Class ('other', 'Female', '[70-80)'): 0.0112
#   Class ('other', 'Female', '[80-100)'): 0.0253
#   Class ('other', 'Male', '[0-40)'): 0.1343
#   Class ('other', 'Male', '[40-50)'): 0.0178
#   Class ('other', 'Male', '[50-60)'): 0.0342
#   Class ('other', 'Male', '[60-70)'): 0.0098
#   Class ('other', 'Male', '[70-80)'): 0.0100
#   Class ('other', 'Male', '[80-100)'): 0.0110
#
# A1Cresult:
#   Class ('AfricanAmerican', 'Female', '[0-40)'): 0.1508
#   Class ('AfricanAmerican', 'Female', '[40-50)'): 0.0420
#   Class ('AfricanAmerican', 'Female', '[50-60)'): 0.0406
#   Class ('AfricanAmerican', 'Female', '[60-70)'): 0.0495
#   Class ('AfricanAmerican', 'Female', '[70-80)'): 0.0245
#   Class ('AfricanAmerican', 'Female', '[80-100)'): 0.0483
#   Class ('AfricanAmerican', 'Male', '[0-40)'): 0.1870
#   Class ('AfricanAmerican', 'Male', '[40-50)'): 0.1313
#   Class ('AfricanAmerican', 'Male', '[50-60)'): 0.0631
#   Class ('AfricanAmerican', 'Male', '[60-70)'): 0.0239
#   Class ('AfricanAmerican', 'Male', '[70-80)'): 0.0269
#   Class ('AfricanAmerican', 'Male', '[80-100)'): 0.0485
#   Class ('Caucasian', 'Female', '[0-40)'): 0.1177
#   Class ('Caucasian', 'Female', '[40-50)'): 0.0523
#   Class ('Caucasian', 'Female', '[50-60)'): 0.0184
#   Class ('Caucasian', 'Female', '[60-70)'): 0.0187
#   Class ('Caucasian', 'Female', '[70-80)'): 0.0420
#   Class ('Caucasian', 'Female', '[80-100)'): 0.0440
#   Class ('Caucasian', 'Male', '[0-40)'): 0.1652
#   Class ('Caucasian', 'Male', '[40-50)'): 0.0840
#   Class ('Caucasian', 'Male', '[50-60)'): 0.0428
#   Class ('Caucasian', 'Male', '[60-70)'): 0.0135
#   Class ('Caucasian', 'Male', '[70-80)'): 0.0426
#   Class ('Caucasian', 'Male', '[80-100)'): 0.0491
#   Class ('other', 'Female', '[0-40)'): 0.1270
#   Class ('other', 'Female', '[40-50)'): 0.0747
#   Class ('other', 'Female', '[50-60)'): 0.0865
#   Class ('other', 'Female', '[60-70)'): 0.0444
#   Class ('other', 'Female', '[70-80)'): 0.0302
#   Class ('other', 'Female', '[80-100)'): 0.0295
#   Class ('other', 'Male', '[0-40)'): 0.2101
#   Class ('other', 'Male', '[40-50)'): 0.1093
#   Class ('other', 'Male', '[50-60)'): 0.0681
#   Class ('other', 'Male', '[60-70)'): 0.0584
#   Class ('other', 'Male', '[70-80)'): 0.0421
#   Class ('other', 'Male', '[80-100)'): 0.0701
#
# readmitted:
#   Class ('AfricanAmerican', 'Female', '[0-40)'): 0.0040
#   Class ('AfricanAmerican', 'Female', '[40-50)'): 0.0067
#   Class ('AfricanAmerican', 'Female', '[50-60)'): 0.0180
#   Class ('AfricanAmerican', 'Female', '[60-70)'): 0.0017
#   Class ('AfricanAmerican', 'Female', '[70-80)'): 0.0113
#   Class ('AfricanAmerican', 'Female', '[80-100)'): 0.0041
#   Class ('AfricanAmerican', 'Male', '[0-40)'): 0.0086
#   Class ('AfricanAmerican', 'Male', '[40-50)'): 0.0094
#   Class ('AfricanAmerican', 'Male', '[50-60)'): 0.0081
#   Class ('AfricanAmerican', 'Male', '[60-70)'): 0.0093
#   Class ('AfricanAmerican', 'Male', '[70-80)'): 0.0004
#   Class ('AfricanAmerican', 'Male', '[80-100)'): 0.0014
#   Class ('Caucasian', 'Female', '[0-40)'): 0.0204
#   Class ('Caucasian', 'Female', '[40-50)'): 0.0074
#   Class ('Caucasian', 'Female', '[50-60)'): 0.0064
#   Class ('Caucasian', 'Female', '[60-70)'): 0.0023
#   Class ('Caucasian', 'Female', '[70-80)'): 0.0051
#   Class ('Caucasian', 'Female', '[80-100)'): 0.0102
#   Class ('Caucasian', 'Male', '[0-40)'): 0.0096
#   Class ('Caucasian', 'Male', '[40-50)'): 0.0133
#   Class ('Caucasian', 'Male', '[50-60)'): 0.0181
#   Class ('Caucasian', 'Male', '[60-70)'): 0.0023
#   Class ('Caucasian', 'Male', '[70-80)'): 0.0083
#   Class ('Caucasian', 'Male', '[80-100)'): 0.0056
#   Class ('other', 'Female', '[0-40)'): 0.0466
#   Class ('other', 'Female', '[40-50)'): 0.0434
#   Class ('other', 'Female', '[50-60)'): 0.0469
#   Class ('other', 'Female', '[60-70)'): 0.0088
#   Class ('other', 'Female', '[70-80)'): 0.0105
#   Class ('other', 'Female', '[80-100)'): 0.0089
#   Class ('other', 'Male', '[0-40)'): 0.0618
#   Class ('other', 'Male', '[40-50)'): 0.0070
#   Class ('other', 'Male', '[50-60)'): 0.0382
#   Class ('other', 'Male', '[60-70)'): 0.0187
#   Class ('other', 'Male', '[70-80)'): 0.0028
#   Class ('other', 'Male', '[80-100)'): 0.0387
#
# T-values DataFrame:
#                                     diag_1    diag_2    diag_3  max_glu_serum  \
# AfricanAmerican Female [0-40)    0.903451  0.682587  0.478546       0.062696
#                        [40-50)   0.203911  0.179230  0.118381       0.031206
#                        [50-60)   0.122156  0.070694  0.049239       0.062665
#                        [60-70)   0.067444  0.137129  0.066023       0.055328
#                        [70-80)   0.164167  0.106005  0.119612       0.049520
#                        [80-100)  0.124516  0.259297  0.138184       0.047693
#                 Male   [0-40)    0.745247  0.746189  0.386800       0.036740
#                        [40-50)   0.370452  0.368342  0.231377       0.017131
#                        [50-60)   0.211071  0.147495  0.104350       0.059729
#                        [60-70)   0.214178  0.133845  0.086207       0.044825
#                        [70-80)   0.225714  0.213074  0.074817       0.056830
#                        [80-100)  0.384201  0.235781  0.113515       0.067872
# Caucasian       Female [0-40)    0.900262  0.788186  0.611805       0.020459
#                        [40-50)   0.229458  0.246648  0.172453       0.014967
#                        [50-60)   0.153031  0.187192  0.072394       0.006623
#                        [60-70)   0.199948  0.137483  0.041969       0.003536
#                        [70-80)   0.131810  0.104891  0.090761       0.022128
#                        [80-100)  0.122648  0.153362  0.089122       0.036330
#                 Male   [0-40)    0.650248  0.520164  0.332459       0.023238
#                        [40-50)   0.249794  0.225457  0.264355       0.023824
#                        [50-60)   0.191609  0.064001  0.153532       0.003379
#                        [60-70)   0.132302  0.078917  0.064870       0.020150
#                        [70-80)   0.124228  0.145759  0.083351       0.019254
#                        [80-100)  0.110216  0.209722  0.124320       0.030505
# other           Female [0-40)    1.891985  1.596605  0.900033       0.019291
#                        [40-50)   0.382353  0.470680  0.258725       0.044530
#                        [50-60)   0.150371  0.222621  0.125839       0.028535
#                        [60-70)   0.235390  0.290636  0.134014       0.025758
#                        [70-80)   0.100994  0.182642  0.092887       0.011229
#                        [80-100)  0.119403  0.105082  0.091962       0.025302
#                 Male   [0-40)    0.513335  0.453949  0.341592       0.134276
#                        [40-50)   0.281580  0.288861  0.211199       0.017750
#                        [50-60)   0.159392  0.154384  0.102140       0.034156
#                        [60-70)   0.208638  0.275951  0.191059       0.009824
#                        [70-80)   0.157662  0.171431  0.140325       0.010048
#                        [80-100)  0.234523  0.172530  0.170234       0.011044
#
#                                  A1Cresult  readmitted
# AfricanAmerican Female [0-40)     0.150821    0.004008
#                        [40-50)    0.042049    0.006691
#                        [50-60)    0.040565    0.017992
#                        [60-70)    0.049523    0.001681
#                        [70-80)    0.024502    0.011255
#                        [80-100)   0.048302    0.004147
#                 Male   [0-40)     0.187048    0.008563
#                        [40-50)    0.131313    0.009365
#                        [50-60)    0.063145    0.008096
#                        [60-70)    0.023854    0.009307
#                        [70-80)    0.026911    0.000403
#                        [80-100)   0.048501    0.001448
# Caucasian       Female [0-40)     0.117717    0.020412
#                        [40-50)    0.052267    0.007400
#                        [50-60)    0.018425    0.006368
#                        [60-70)    0.018666    0.002265
#                        [70-80)    0.042006    0.005098
#                        [80-100)   0.043951    0.010243
#                 Male   [0-40)     0.165215    0.009575
#                        [40-50)    0.083970    0.013288
#                        [50-60)    0.042784    0.018072
#                        [60-70)    0.013540    0.002261
#                        [70-80)    0.042589    0.008314
#                        [80-100)   0.049083    0.005586
# other           Female [0-40)     0.127002    0.046587
#                        [40-50)    0.074682    0.043353
#                        [50-60)    0.086511    0.046854
#                        [60-70)    0.044402    0.008761
#                        [70-80)    0.030196    0.010450
#                        [80-100)   0.029534    0.008900
#                 Male   [0-40)     0.210117    0.061829
#                        [40-50)    0.109314    0.007002
#                        [50-60)    0.068108    0.038165
#                        [60-70)    0.058447    0.018693
#                        [70-80)    0.042147    0.002804
#                        [80-100)   0.070085    0.038687

# %%
import pandas as pd
from scipy.stats import wasserstein_distance
import numpy as np
import matplotlib.pyplot as plt

def calculate_distribution(series, all_categories=None):
    counts = series.value_counts(normalize=True)
    if all_categories is not None:
        counts = counts.reindex(all_categories, fill_value=0)
    return counts

def earth_mover_distance_numeric(p, q):
    return wasserstein_distance(p, q)

def earth_mover_distance_categorical(p, q):
    p, q = p.align(q, fill_value=0)
    categories = np.arange(len(p))
    return wasserstein_distance(categories, categories, p.values, q.values)

def calculate_t_closeness_emd(df, quasi_identifiers, sensitive_attribute, attribute_type='categorical'):
    global_distribution = calculate_distribution(df[sensitive_attribute])
    all_categories = global_distribution.index
    t_values = {}
    
    grouped = df.groupby(quasi_identifiers)
    for group_key, group_df in grouped:
        class_distribution = calculate_distribution(group_df[sensitive_attribute], all_categories)
        
        if attribute_type == 'numerical':
            emd = earth_mover_distance_numeric(global_distribution.values, class_distribution.values)
        else:
            emd = earth_mover_distance_categorical(global_distribution, class_distribution)
        
        t_values[group_key] = emd
    
    return t_values, global_distribution, all_categories

def adjust_to_t_closeness(df, quasi_identifiers, sensitive_attributes, attribute_types, t):
    adjusted_df = df.copy()
    original_len = len(adjusted_df)
    
    for sensitive_attribute, attribute_type in zip(sensitive_attributes, attribute_types):
        t_values, global_distribution, all_categories = calculate_t_closeness_emd(adjusted_df, quasi_identifiers, sensitive_attribute, attribute_type)
        
        for group_key, emd in t_values.items():
            while emd > t:
                try:
                    group_df = adjusted_df.groupby(quasi_identifiers).get_group(group_key)
                    if group_df.empty:
                        break
                    if attribute_type == 'categorical':
                        most_common_value = group_df[sensitive_attribute].mode()[0]
                        rows_to_delete = group_df[group_df[sensitive_attribute] == most_common_value].index
                        adjusted_df = adjusted_df.drop(rows_to_delete)
                    elif attribute_type == 'numerical':
                        median_value = group_df[sensitive_attribute].median()
                        rows_to_delete = group_df[group_df[sensitive_attribute] == median_value].index
                        adjusted_df = adjusted_df.drop(rows_to_delete)
                    
                    group_df = adjusted_df.groupby(quasi_identifiers).get_group(group_key)
                    class_distribution = calculate_distribution(group_df[sensitive_attribute], all_categories)
                    if attribute_type == 'categorical':
                        emd = earth_mover_distance_categorical(global_distribution, class_distribution)
                    else:
                        emd = earth_mover_distance_numeric(global_distribution.values, class_distribution.values)
                
                except KeyError:
                    break
    
    data_loss = 1 - len(adjusted_df) / original_len
    return adjusted_df, data_loss


quasi_identifiers = ['race', 'gender', 'age']
sensitive_attributes = ['diag_1', 'diag_2', 'diag_3', 'max_glu_serum', 'A1Cresult', 'readmitted']
attribute_types = ['categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'categorical']

# Range of t values to test
t_values = [0.25, 0.5, 0.75, 1]

# Store results
adjusted_dfs = []
data_losses = []

for t in t_values:
    # Adjust the dataset to satisfy t-closeness
    adjusted_df, data_loss = adjust_to_t_closeness(df, quasi_identifiers, sensitive_attributes, attribute_types, t)
    adjusted_dfs.append((t, adjusted_df))
    data_losses.append((t, data_loss))

# Print data loss
for t, data_loss in data_losses:
    print(f"t = {t}: Data Loss = {data_loss:.2%}")

# Plot the results
original_len = len(df)
adjusted_lengths = [len(adjusted_df) for _, adjusted_df in adjusted_dfs]

plt.figure(figsize=(10, 6))
plt.plot([0] + t_values, [original_len] + adjusted_lengths, marker='o', label='Adjusted DataFrame Length')
plt.axhline(y=original_len, color='r', linestyle='--', label='Original DataFrame Length')
plt.xlabel('t-closeness Threshold')
plt.ylabel('Number of Records')
plt.title('Data Loss with Different t-closeness Thresholds')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# t = 0.25: Data Loss = 19.88%
# t = 0.5: Data Loss = 6.51%
# t = 0.75: Data Loss = 3.70%
# t = 1: Data Loss = 0.32%
